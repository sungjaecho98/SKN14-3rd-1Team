# %% [markdown]
# #  이미지 URL 매핑 자동화

# %%
# !pip install langchain langchain-openai langchain-pinecone langchain-community

# %%
from google.colab import userdata
import os

os.environ['LANGSMITH_TRACING'] = userdata.get('LANGSMITH_TRACING')
os.environ['LANGSMITH_ENDPOINT'] = userdata.get('LANGSMITH_ENDPOINT')
os.environ['LANGSMITH_API_KEY'] = userdata.get('LANGSMITH_API_KEY')
os.environ['LANGSMITH_PROJECT'] = userdata.get('LANGSMITH_PROJECT')
os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# %%
os.environ['OPENAI_EMBEDDING_MODEL'] = userdata.get('OPENAI_EMBEDDING_MODEL')
# os.environ['PINECONE_API_KEY'] = userdata.get('PINECONE_API_KEY')
os.environ['PINECONE_API_KEY'] = userdata.get('SHPINECONE_API_KEY')
os.environ['GOOGLE_CSE_ID'] = userdata.get('GOOGLE_CSE_ID')
os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

# %%
# SungJaeCho/data_refine.py

import os
import time
import requests
from pprint import pprint
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_pinecone import PineconeVectorStore
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pinecone import Pinecone
from langchain.chains import RetrievalQA

def fetch_image_url(query: str, cse_id: str, api_key: str) -> str:
    import requests

    url = "https://www.googleapis.com/customsearch/v1"
    params = {
        "q": query,
        "cx": cse_id,
        "key": api_key,
        "searchType": "image",
        "num": 1,  # 1장만 받기
        "imgSize": "medium",  # medium, large, xlarge
        "safe": "active"
    }

    try:
        response = requests.get(url, params=params, timeout=5)
        response.raise_for_status()
        results = response.json()
        items = results.get("items", [])
        if items:
            return items[0]["link"]
    except Exception as e:
        print(f"🔴 Google Image Search 실패: {e}")

    return ""


# ------------------------
# 1. API 응답 -> LangChain Document 변환 함수
# ------------------------
def json_to_documents(api_json: dict) -> list[Document]:
    documents = []

    # Google API 키 및 CSE ID 환경변수에서 가져오기
    google_cse_id = os.environ['GOOGLE_CSE_ID']
    google_api_key = os.environ['GOOGLE_API_KEY']


    for entry in api_json['body']['items']:
        data = entry['item']

        def get_and_strip(data_dict, key):
            value = data_dict.get(key)
            return value.strip() if isinstance(value, str) else ''

        product_name = get_and_strip(data, 'PRDUCT')
        manufacturer = get_and_strip(data, 'ENTRPS')
        image_url = ""
        # Google API 키와 CSE ID가 모두 있을 경우에만 이미지 검색 수행
        if google_cse_id and google_api_key and product_name:
            query = f"{product_name} {manufacturer}" # 제품명과 제조사를 함께 검색 쿼리로 사용
            image_url = fetch_image_url(query, google_cse_id, google_api_key)

        text = f"""
제품명: {product_name}
제조사: {manufacturer}
기능성: {get_and_strip(data, 'MAIN_FNCTN')}
섭취 시 주의사항: {get_and_strip(data, 'INTAKE_HINT1')}
보관조건: {get_and_strip(data, 'PRSRV_PD')}
유통기한: {get_and_strip(data, 'DISTB_PD')}
섭취량&섭취방법: {get_and_strip(data, 'SRV_USE')}
"""

        metadata = {
            "제품명": product_name,
            "등록일자": data.get("STTEMNT_NO"),
            "제조사": manufacturer,
            "기준규격": get_and_strip(data, "BASE_STANDARD"),
            "이미지URL": image_url
        }

        documents.append(Document(page_content=text, metadata=metadata))

    return documents

# ------------------------
# 2. 전체 페이지 반복 요청하여 모든 문서 수집
# ------------------------
def fetch_all_documents(api_url, api_key, num_of_rows=100) -> list[Document]:
    all_documents = []
    params = {
        "ServiceKey": api_key, # API 키
        "pageNo": "1", # 시작 페이지
        "numOfRows": str(num_of_rows), # 한 페이지에 수집할 문서 수
        "type": "json", # 응답 형식
    } # API 요청 파라미터 설정

    # 일단 첫 페이지 요청
    response = requests.get(api_url, params=params, timeout=10) # API 요청
    response.raise_for_status() # 응답 상태 코드 확인
    first_page = response.json() # 첫 페이지 응답 JSON 파싱

    total_count = int(first_page['body']['totalCount']) # 전체 문서 수 카운트, 1페이지 응답을 통해 전체 문서 수 파악
    total_pages = (total_count // num_of_rows) + (1 if total_count % num_of_rows else 0) # 전체 페이지 수 계산

    # 이미 받은 first_page를 활용해서 문서로 바꾸고 리스트에 추가
    all_documents.extend(json_to_documents(first_page)) # .extend(docs)는 all_documents에 문서들을 낱개로 차곡차곡 넣는 역할

    for page in range(2, total_pages + 1):
        params['pageNo'] = str(page) # 현재 페이지 번호를 API 요청 파라미터에 설정
        response = requests.get(api_url, params=params, timeout=10) # 해당 페이지에 대한 API 요청전송
        response.raise_for_status() # 오류가 있으면 예외 발생시킴 (예: 404, 500)
        page_json = response.json() # 페이지 응답 JSON 파싱
        docs = json_to_documents(page_json) # 해당 페이지의 JSON을 Document 객체로 변환
        all_documents.extend(docs) # 변환된 문서들을 all_documents 리스트에 추가
        print(f"📄 {page}/{total_pages} 페이지 수집 완료")

    print(f"\n✅ 총 {len(all_documents)}개의 Document 객체 생성 완료")
    return all_documents

# def fetch_all_documents(api_url, api_key, num_of_rows=100, test_pages=1) -> list[Document]:
#     all_documents = []
#     params = {
#         "ServiceKey": api_key,
#         "pageNo": "1",
#         "numOfRows": str(num_of_rows),
#         "type": "json",
#     }

#     response = requests.get(api_url, params=params, timeout=10)
#     response.raise_for_status()
#     first_page = response.json()

#     total_count = int(first_page['body']['totalCount'])
#     total_pages = (total_count // num_of_rows) + (1 if total_count % num_of_rows else 0)

#     # 테스트: test_pages 만큼만 수집
#     all_documents.extend(json_to_documents(first_page))

#     for page in range(2, min(test_pages, total_pages) + 1):
#         params['pageNo'] = str(page)
#         response = requests.get(api_url, params=params, timeout=10)
#         response.raise_for_status()
#         page_json = response.json()
#         docs = json_to_documents(page_json)
#         all_documents.extend(docs)
#         print(f"📄 {page}/{total_pages} 페이지 수집 완료 (테스트)")

#     print(f"\n✅ (테스트) 총 {len(all_documents)}개의 Document 객체 생성 완료")
#     return all_documents

# ------------------------
# 3. 벡터스토어 생성 및 문서 업로드
# ------------------------
# def build_vector_store(documents, index_name):
#     embeddings = OpenAIEmbeddings(model=os.environ['OPENAI_EMBEDDING_MODEL'])

#     # 문서 분할
#     text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
#     split_documents = text_splitter.split_documents(documents)

#     # Pinecone 초기화 및 인덱스 준비
#     pc = Pinecone(api_key=os.environ['PINECONE_API_KEY'])

#     if index_name not in pc.list_indexes().names():
#         pc.create_index(
#             name=index_name,
#             dimension=embeddings.get_dimension(),
#             metric='cosine'
#         )
#         while not pc.describe_index(index_name).status['ready']:
#             time.sleep(1)

#     vector_store = PineconeVectorStore(index_name=index_name, embedding=embeddings)

#     # 배치 업로드
#     batch_size = 100
#     for i in range(0, len(split_documents), batch_size):
#         batch = split_documents[i:i + batch_size]
#         # vector_store.add_documents(batch)  # 주석 해제 시 실제 업로드 수행
#         print(f"Added batch {i//batch_size + 1}/{(len(split_documents)//batch_size) + 1}")

#     print("\n✅ All documents added to Pinecone vector store.")
#     return vector_store
def build_vector_store(documents, index_name):
    embeddings = OpenAIEmbeddings(model=os.environ['OPENAI_EMBEDDING_MODEL'])
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
    split_documents = text_splitter.split_documents(documents)

    pc = Pinecone(api_key=os.environ['PINECONE_API_KEY'])

    if index_name not in pc.list_indexes().names():
        pc.create_index(
            name=index_name,
            dimension=embeddings.get_dimension(),
            metric='cosine'
        )
        while not pc.describe_index(index_name).status['ready']:
            time.sleep(1)

    vector_store = PineconeVectorStore(index_name=index_name, embedding=embeddings)

    batch_size = 100
    for i in range(0, len(split_documents), batch_size):
        batch = split_documents[i:i + batch_size]
        # 실제 업로드는 주석 처리 (테스트)
        vector_store.add_documents(batch)
        print(f"(테스트) Added batch {i//batch_size + 1}/{(len(split_documents)//batch_size) + 1}")

    print("\n✅ (테스트) All documents processed for Pinecone vector store.")
    return vector_store


# ------------------------
# 4. RAG 질의 시스템 구성
# ------------------------
def build_qa_chain(vector_store):
    retriever = vector_store.as_retriever(
        search_type='similarity',
        search_kwargs={'k': 3}
    )

    llm = ChatOpenAI(
        model_name="gpt-4.1-mini",
        temperature=0.3,
        max_tokens=512
    )

    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        retriever=retriever,
        chain_type="stuff",
        return_source_documents=True
    )
    return qa_chain

# ------------------------
# 5. 메인 실행부 예시
# ------------------------
if __name__ == "__main__":
    url = 'http://apis.data.go.kr/1471000/HtfsInfoService03/getHtfsItem01'
    api_key = 'nsfVX4dKQRFTeyldmuRefFQqL8xOsDkkyw8TsU4dA4fO9vq7Zl7JTbrakHnVYBqRG62CWBhhOVwBaGgCBbm3AA=='

    # Step 1: 문서 수집
    documents = fetch_all_documents(url, api_key)

    # Step 2: 벡터스토어 생성 및 문서 업로드
    index_name = 'health-supplement-rag'
    vector_store = build_vector_store(documents, index_name)

    # Step 3: 질의 응답 시스템 구축
    qa_chain = build_qa_chain(vector_store)

    # Step 4: 사용자 질의 처리
    query = "피로개선에 도움이 되는 영양제는?"
    response = qa_chain(query)

    print("\n🧠 GPT 응답:")
    print(response['result'])

    print("\n📎 참고 문서:")
    for doc in response['source_documents'][:3]:
        print(f"제품명: {doc.metadata['제품명']} | 제조사: {doc.metadata['제조사']} | 등록일자: {doc.metadata['등록일자']}")
        print(f"이미지URL: {doc.metadata.get('이미지URL', '')}")
        print("-" * 60)

# if __name__ == "__main__":
#     url = 'http://apis.data.go.kr/1471000/HtfsInfoService03/getHtfsItem01'
#     api_key = 'nsfVX4dKQRFTeyldmuRefFQqL8xOsDkkyw8TsU4dA4fO9vq7Zl7JTbrakHnVYBqRG62CWBhhOVwBaGgCBbm3AA=='

#     # Step 1: 문서 수집 (테스트: 2페이지만 수집)
#     documents = fetch_all_documents(url, api_key, num_of_rows=10, test_pages=2)

#     # Step 2: 벡터스토어 생성 및 문서 업로드 (실제 업로드는 주석 처리)
#     index_name = 'health-supplement-rag-test'
#     vector_store = build_vector_store(documents, index_name)

#     # Step 3: 질의 응답 시스템 구축
#     qa_chain = build_qa_chain(vector_store)

#     # Step 4: 사용자 질의 처리
#     query = "피로개선에 도움이 되는 영양제는?"
#     response = qa_chain(query)

#     print("\n🧠 GPT 응답:")
#     print(response['result'])

#     print("\n📎 참고 문서:")
#     for doc in response['source_documents']:
#         print(f"제품명: {doc.metadata['제품명']} | 제조사: {doc.metadata['제조사']} | 등록일자: {doc.metadata['등록일자']}")
#         print(f"이미지URL: {doc.metadata.get('이미지URL', '')}")
#         print("-" * 60)
# Out:
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=11%EC%A2%85+%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0+%EC%9D%BC%EB%8F%99%EB%B0%94%EC%9D%B4%EC%98%A4%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=6%EB%85%84%EA%B7%BC+%EA%B3%A0%EB%A0%A4%ED%99%8D%EC%82%BC%EC%A0%95+PREMIUM+%EC%A3%BC%EC%8B%9D%ED%9A%8C%EC%82%AC+%EC%84%B1%EC%9C%A4+%EC%97%90%ED%94%84%EC%97%94%EC%A7%80%28F%26G%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=6%EB%85%84%EA%B7%BC+%ED%99%8D%EC%82%BC+%EC%9E%90%EC%8B%A0%EB%A7%8C%EB%A7%8C+%ED%99%8D%EC%82%BC%EC%8A%A4%ED%8B%B1+%28%EC%A3%BC%29%EC%9D%BC%ED%99%94&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=ATOMY+VITAMIN+C%28%EB%B8%8C%EB%9D%BC%EC%A7%88%29+%EC%BD%9C%EB%A7%88%EB%B9%84%EC%95%A4%EC%97%90%EC%9D%B4%EC%B9%98%28%EC%A3%BC%29%EC%84%B8%EC%A2%853%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=CosmeHeal+HEALTHY+WHITE+EfferGlow%28%EC%88%98%EC%B6%9C%EC%9A%A9%29%C2%A0%28%EC%BD%94%EC%8A%A4%EB%A9%94%ED%9E%90+%ED%97%AC%EC%94%A8+%ED%99%94%EC%9D%B4%ED%8A%B8%2C+%EC%97%90%ED%8D%BC%EA%B8%80%EB%A1%9C%EC%9A%B0%EF%BB%BF%29+%EC%97%90%ED%94%84%EC%97%94%EB%B0%94%EC%9D%B4%EC%98%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=Ento+Probiotics+plus+Blood+sugar+care+%28%EC%A0%84%EB%9F%89%EC%88%98%EC%B6%9C%EC%9A%A9%29+%EC%A3%BC%EC%8B%9D%ED%9A%8C%EC%82%AC+%EC%95%84%EB%9E%8C&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=KA-NE+PLUS+ZINC+%28%EC%88%98%EC%B6%9C%EC%9A%A9%29+%EC%97%90%ED%94%84%EC%97%94%EB%B0%94%EC%9D%B4%EC%98%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=L-Ergo+Admixture%28%EC%A0%84%EB%9F%89%EC%88%98%EC%B6%9C%EC%9A%A9%29+%EC%BD%94%EC%8A%A4%EB%A7%A5%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=Puffing+red+ginseng+extract+powder-J+%28%EC%A3%BC%29%EA%B7%B8%EB%A6%B0%EB%B0%94%EC%9D%B4%EC%98%A4&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EA%B3%A0%EB%A0%A4%ED%99%8D%EC%82%BC%EB%86%8D%EC%B6%95%EC%95%A1%2823mg%2Fg%29+%EC%BC%80%EC%9D%B4%EC%A7%80%EB%9E%A9+%EC%A3%BC%EC%8B%9D%ED%9A%8C%EC%82%AC&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%82%99%EC%82%B0%EA%B7%A0%28Naksan%29%28%EC%88%98%EC%B6%9C%EC%9A%A9%29+%EC%97%94%ED%94%BC%EC%BC%80%EC%9D%B4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%82%A8%EC%84%B1%EA%B1%B4%EA%B0%95%EC%97%94+%EC%8F%98%ED%8C%94%EB%A9%94%ED%86%A0+%EC%98%A5%ED%83%80%EC%BD%94%EC%82%AC%EB%86%80+%28%EC%A3%BC%29%EC%BC%80%EC%9D%B4%EC%A7%80%EC%95%A4%EC%97%90%ED%94%84&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%84%A4%EC%9D%B4%EC%B2%98%EB%93%9C%EB%A6%BC+%ED%98%88%ED%96%89%EC%97%90+%EC%A2%8B%EC%9D%80+%EC%95%8C%ED%8B%B0%EC%A7%80+%EC%98%A4%EB%A9%94%EA%B0%803+%EA%B3%A8%EB%93%9C+%EC%A3%BC%EC%8B%9D%ED%9A%8C%EC%82%AC%ED%95%9C%EB%AF%B8%EC%96%91%ED%96%89&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%89%B4+%EB%A7%88%EA%B7%B8%EB%84%A4%EC%8A%98350%2BB6+%EC%97%94%ED%94%BC%EC%BC%80%EC%9D%B4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%89%B4%ED%8A%B8%EC%9B%90%EB%B9%84%ED%83%80%EB%AF%BCD%EC%9C%A0%EA%B8%B0%EB%86%8D1000IU+%28%EC%A3%BC%29%ED%95%9C%EA%B5%AD%EC%94%A8%EC%97%94%EC%97%90%EC%8A%A4%ED%8C%9C&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%8B%A4%EB%8B%88%EC%8A%A4%EC%BD%94+5%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0+100B+%28%EC%A3%BC%29%EC%BC%80%EB%B9%84%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%8B%B9+%EC%BC%80%EC%96%B4+%28%EC%A3%BC%29%ED%99%94%EC%A7%84%EB%B0%94%EC%9D%B4%EC%98%A4%EC%BD%94%EC%8A%A4%EB%A9%94%ED%8B%B1&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%8D%B0%EC%9D%BC%EB%A6%AC+%ED%8D%BC%ED%94%8C+%ED%82%A4%EC%A6%88+%EB%A9%80%ED%8B%B0%EB%B9%84%ED%83%80%EC%A0%A4%EB%A6%AC+%EC%BD%94%EC%8A%A4%EB%A7%A5%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%9D%BD%ED%86%A0%EC%BD%94%EC%BB%A4%EC%8A%A4+%EB%9D%BD%ED%8B%B0%EC%8A%A4+LCL-10%C2%AE+%28%EC%A3%BC%29%EB%B0%94%EC%9D%B4%ED%85%8D+%EC%9D%B5%EC%82%B0%EC%A7%80%EC%A0%90&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%9D%BD%ED%8B%B0%ED%94%8C%EB%9E%9C%ED%8B%B0%EB%B0%94%EC%8B%A4%EB%9F%AC%EC%8A%A4+%ED%94%8C%EB%9E%80%ED%83%80%EB%A3%B8+%EC%97%90%EC%9D%B4%EC%B9%98%EC%97%98%EC%98%A4%EC%97%90%EC%8A%A4%EB%B9%8422+%28Lactiplantibacillus+plantarum+HLOSB22%29+%EC%A3%BC%EC%8B%9D%ED%9A%8C%EC%82%AC+%ED%98%84%EB%8C%80%EB%B0%94%EC%9D%B4%EC%98%A4%EB%9E%9C%EB%93%9C+%EC%95%88%EC%82%B0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%A1%9C%EC%96%84%ED%95%9C%EA%B5%AD%EC%A0%81%EC%86%A1%28%EC%A0%84%EB%9F%89%EC%88%98%EC%B6%9C%EC%9A%A9%29+%EC%BD%94%EC%8A%A4%EB%A7%A5%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%A7%88%EC%9D%B4%ED%95%8FV%EB%A9%80%ED%8B%B0%EB%B9%84%ED%83%80%EC%9D%B4%EB%AE%A8128+%EC%A3%BC%EC%8B%9D%ED%9A%8C%EC%82%AC+%EB%84%A4%EC%B6%94%EB%9F%B4%EC%9B%A8%EC%9D%B4+%ED%8F%AC%EC%B2%9C+%EC%A0%9C2%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%B9%84%EC%98%A4%ED%8B%B4+%ED%9A%A8%EB%AA%A8+%EB%8D%94+%EC%B1%84%EC%9B%80+%EC%97%94%ED%94%BC%EC%BC%80%EC%9D%B4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EB%B9%84%ED%83%80%EB%AF%BCB+%EC%BB%B4%ED%94%8C%EB%A0%89%EC%8A%A4+%28%EC%A3%BC%29%EC%84%9C%ED%9D%A5%ED%97%AC%EC%8A%A4%EC%BC%80%EC%96%B4+2%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EC%93%B0%EB%A6%AC%ED%94%8C%EB%A0%89%EC%8A%A4+%EC%BD%9C%EB%A0%88%EC%8A%A4%ED%85%8C%EB%A1%A4%E2%88%99+%ED%98%88%EB%8B%B9+%E2%88%99%ED%98%88%EC%95%95+%28%EC%A3%BC%29%EC%BC%80%EC%9D%B4%EC%A7%80%EC%95%A4%EC%97%90%ED%94%84&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EC%95%84%EC%8A%A4%ED%83%80%C2%B7%EC%98%A4%EB%A9%94%EA%B0%80+%28%EC%A3%BC%29%ED%95%9C%ED%92%8D%EB%84%A4%EC%9D%B4%EC%B2%98%ED%8C%9C&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EC%98%A8%EC%9C%A0%EB%A1%9C%EC%BC%80%EC%96%B4+%EC%B1%84%EC%9B%80%EB%A3%A8%ED%8B%B4+%EB%B8%94%EB%9E%99+%ED%8F%AC%EC%9A%B0%EB%A8%BC+%EB%B9%84%EC%98%A4%ED%8B%B4+%ED%9E%88%EC%95%8C%EB%A3%A8%EB%A1%A0%EC%82%B0+%28%EC%A3%BC%29%ED%95%9C%ED%92%8D%EB%84%A4%EC%9D%B4%EC%B2%98%ED%8C%9C&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EC%A0%9C%EC%A3%BC%EB%8F%84%ED%8C%94%EB%A7%88%EB%A7%88%EB%A0%A5%EC%A0%95%28%EC%A0%84%EB%9F%89%EC%88%98%EC%B6%9C%EC%9A%A9%29+%EB%86%8D%EC%97%85%ED%9A%8C%EC%82%AC%EB%B2%95%EC%9D%B8%EC%A7%80%EC%97%90%EC%9D%B4%EC%B9%98%EB%82%B4%EC%B8%84%EB%9F%B4&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%EC%A4%91%EC%9B%90%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%EC%9C%A0%EC%82%B0%EA%B7%A0+%28%EC%A3%BC%29%EC%A4%91%EC%9B%90%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%ED%98%88%EB%8B%B9%EB%A7%88%EC%8A%A4%ED%84%B0+%28Diabet+master%29%28%EC%88%98%EC%B6%9C%EC%9A%A9%29+%EC%97%94%ED%94%BC%EC%BC%80%EC%9D%B4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%ED%99%8D%EC%82%BC%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84%EC%9C%A0%EC%82%B0%EA%B7%A0+%EC%97%A0%EC%97%90%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%ED%85%8D%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%ED%99%A9%EC%9E%91+%ED%99%A9%EC%9E%91%EA%B3%A0+%28%EC%A3%BC%29%EC%9D%BC%ED%99%94&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%ED%9D%91%EC%82%BC%EC%A0%95%EC%97%90%ED%94%84+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%96%B8%EC%8A%A4&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%27%EA%B0%84%27%ED%8E%B8%ED%95%A8%EC%9D%84+%EB%88%84%EB%A6%AC%EB%8B%A4+%EB%B0%80%ED%81%AC%EC%94%A8%EC%8A%AC+%EA%B0%84+%E8%82%9D+%28%EC%A3%BC%29%ED%95%9C%ED%92%8D%EB%84%A4%EC%9D%B4%EC%B2%98%ED%8C%9C&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28Heun%29+Love+Your+Body+Weight+Management+for+diet+%EB%8F%99%EC%84%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C%28%EC%A3%BC%29+%EC%95%88%EC%84%B1%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28SS%29%EC%97%90%EC%8A%A4%EC%97%90%EC%8A%A4%EC%8A%A4%ED%82%A8%EC%86%94%EB%A3%A8%EC%85%98+%EC%97%90%EC%8A%A4%EC%97%90%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28SS%29%EC%97%90%EC%8A%A4%EC%97%90%EC%8A%A4%ED%98%88%ED%96%89%EC%86%94%EB%A3%A8%EC%85%98+%EC%97%90%EC%8A%A4%EC%97%90%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28SS%29%EC%97%90%EC%8A%A4%EC%97%90%EC%8A%A4%ED%98%88%ED%96%89%EC%BC%80%EC%96%B4+%EC%97%90%EC%8A%A4%EC%97%90%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EA%B5%AC%29+%EB%88%88%EC%97%90%EC%A2%8B%EC%9D%80+%EB%A3%A8%ED%85%8C%EC%9D%B8%2B%EC%98%A4%EB%A9%94%EA%B0%803+%28%EC%A3%BC%29%EC%84%9C%ED%9D%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EA%B5%AC%29+%EB%AC%B4%EB%A5%B4%ED%95%80+%28%EC%A3%BC%29%EC%84%9C%ED%9D%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EA%B5%AC%29+%EC%A0%80%EB%9E%98%EB%8F%84+%EC%98%B9+%28%EC%A3%BC%29%EC%94%A8%ED%8B%B0%EC%94%A8%EB%B0%94%EC%9D%B4%EC%98%A4&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EA%B5%AC%29+%ED%8C%BB%EB%8B%A4%EC%9A%B4+%ED%86%A1+%28%EC%A3%BC%29%EC%84%9C%ED%9D%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EA%B5%AC%29%EB%8F%99%EC%95%84%EB%B9%84%ED%83%80%EB%AF%BCC%EC%88%9C%28%E7%B4%94%29+%28%EC%A3%BC%29%EC%84%9C%ED%9D%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EA%B5%AC%29%EB%B3%B8%ED%8F%AC%EB%AE%AC%EB%9F%AC%EC%A0%A4%EB%A6%AC+%28%EC%A3%BC%29%EC%84%9C%ED%9D%A5%ED%97%AC%EC%8A%A4%EC%BC%80%EC%96%B4&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EA%B5%AC%29%EC%B8%84%EC%96%B4%EB%B8%94%EC%98%A4%EB%A9%94%EA%B0%80-3+%28%EC%A3%BC%29%EC%84%9C%ED%9D%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EA%B5%AC%29%ED%8A%B8%EB%A6%AC%ED%94%8C%EB%9F%AC%EC%8A%A4+%28%EC%A3%BC%29%EC%84%9C%ED%9D%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EA%B5%AC%29%ED%94%84%EB%A1%9C%EB%A9%94%EA%B0%80+%EB%A0%88%EB%B3%BC%EB%A3%A8%EC%85%98+%28%EC%A3%BC%29%EC%84%9C%ED%9D%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EC%88%98%EC%B6%9C%EC%9A%A9%29%ED%95%B4%EB%A7%91%EC%9D%80%EC%95%84%EC%B9%A8+%EC%9D%B8%EC%84%B1%EC%A0%9C%EC%95%BD%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EC%88%98%EC%B6%9C%EC%9A%A9%29%ED%95%B4%EB%A7%91%EC%9D%80%EC%95%84%EC%B9%A83+%EC%9D%B8%EC%84%B1%EC%A0%9C%EC%95%BD%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EC%9D%BC%EB%B3%B8%EC%A0%84%EB%9F%89%EC%88%98%EC%B6%9C%EC%9A%A9%29%EB%B9%84%ED%83%80500+%EB%8D%B0%EC%9D%BC%EB%A6%AC%EC%8A%A4%ED%8B%B1+%EC%9D%B4%EC%95%A4%EC%97%90%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EC%A0%84%EB%9F%89%EC%88%98%EC%B6%9C%EC%9A%A9%29%EB%B9%84%ED%83%80%EB%AF%BC+%ED%99%8D%EC%82%BC+%EB%8F%99%EC%B6%A9%ED%95%98%EC%B4%88%28Vitamin+Red+Ginseng+Cordyceps%29+%EC%9D%B4%EC%95%A4%EC%97%90%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EC%A0%84%EB%9F%89%EC%88%98%EC%B6%9C%EC%9A%A9%29%EC%95%84%EC%9D%B4%ED%86%A0%EB%8B%89%ED%94%8C%EB%9F%AC%EC%8A%A4%28Eye+tonic+plus%29+%EC%9D%B4%EC%95%A4%EC%97%90%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%EC%A0%84%EB%9F%89%EC%88%98%EC%B6%9C%EC%9A%A9%29%EC%9D%BC%EB%8F%99+%EC%B2%9C%EB%85%84%EB%B9%84%EC%B1%85+%EC%9D%B4%EC%95%A4%EC%97%90%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%ED%83%9C%EA%B5%AD%EC%A0%84%EB%9F%89%EC%88%98%EC%B6%9C%EC%9A%A9%29%EB%B9%84%ED%83%80500+%EB%8D%B0%EC%9D%BC%EB%A6%AC%EC%8A%A4%ED%8B%B1+%EC%9D%B4%EC%95%A4%EC%97%90%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%28%ED%94%84%EB%A1%9C%ED%8F%B4%EB%A6%AC%EC%8A%A4+%EA%B5%AC%EA%B0%95%EC%8A%A4%ED%94%84%EB%A0%88%EC%9D%B4%29+Propolis+Throat+Spray+%EC%9C%A0%EB%8B%88%ED%81%AC%EB%B0%94%EC%9D%B4%EC%98%A4%ED%85%8D%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%2B+%EB%88%88%EA%B1%B4%EA%B0%95+%28%EC%A3%BC%29%ED%95%9C%EA%B5%AD%EC%94%A8%EC%97%94%EC%97%90%EC%8A%A4%ED%8C%9C&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%2B+%EB%BC%88%EA%B1%B4%EA%B0%95+%28%EC%A3%BC%29%ED%95%9C%ED%92%8D%EB%84%A4%EC%9D%B4%EC%B2%98%ED%8C%9C&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%2B%EB%A9%B4%EC%97%AD%EB%B9%84%EC%B1%85+%EB%B0%9C%ED%9A%A8%ED%99%8D%EC%82%BC+%EA%B4%91%EB%8F%99%ED%97%AC%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%2B%EB%B0%9C%ED%9A%A8%ED%99%8D%EC%82%BC%EC%A7%84+%EA%B4%91%EB%8F%99%ED%97%AC%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%28%EC%A3%BC%29+2%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%2B%EB%B9%84%ED%83%80%EB%AF%BC%EB%AF%B8%EB%84%A4%EB%9E%84+%EA%B4%91%EB%8F%99%ED%97%AC%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%28%EC%A3%BC%29+2%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%2B%EC%9D%B4%EB%84%88%EB%B7%B0%ED%8B%B024h+%EC%BD%94%EC%8A%A4%EB%A7%A5%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%2B%EC%9E%A5%EA%B1%B4%EA%B0%95+%EA%B4%91%EB%8F%99%ED%97%AC%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%28%EC%A3%BC%29+2%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=%2B%EC%B0%A9%ED%95%9C%EB%B9%84%ED%83%80%EB%AF%BCC+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0+%EC%B6%A9%EC%A3%BC%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10+Billion+probiotics+%28%EC%A3%BC%29%ED%95%9C%EB%AF%B8%EC%96%91%ED%96%89+%EC%84%A0%EC%9C%A0%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%25+%EC%8B%9D%EB%AC%BC%EC%84%B1+%EB%8C%80%EB%A7%88%EC%A2%85%EC%9E%90%EC%9C%A0+%EC%9C%A0%EB%9E%98+%ED%95%84%EC%88%98%EC%A7%80%EB%B0%A9%EC%82%B0+%28%EC%A3%BC%29%ED%95%9C%ED%92%8D%EB%84%A4%EC%9D%B4%EC%B2%98%ED%8C%9C&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%25+%EC%8B%9D%EB%AC%BC%EC%84%B1+%ED%94%84%EB%A1%9C%ED%8B%B4+%EC%BC%80%EC%96%B4+%EC%BD%9C%EB%A7%88%EB%B9%84%EC%95%A4%EC%97%90%EC%9D%B4%EC%B9%98%28%EC%A3%BC%29%EC%9D%8C%EC%84%B1%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=1000%2B1000+%EB%B9%84%ED%83%80%EB%AF%BC+%EB%8D%94%EB%B8%94%EC%95%A1%EC%85%98+%EC%9D%B4%EC%95%A4%EC%97%90%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%84%B8%EA%B1%B4%EA%B0%95+365+%EC%97%90%EC%8A%A4%EC%BC%80%EC%9D%B4%EB%82%B4%EC%B6%94%EB%9F%B4%ED%8C%9C%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%84%B8%EA%B1%B4%EA%B0%95365%EB%82%98%ED%86%A0%ED%82%A4%EB%82%98%EC%A0%9C+%28%EC%A3%BC%29%EC%BC%80%EC%9D%B4%EC%A7%80%EC%95%A4%EC%97%90%ED%94%84&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%84%B8%ED%8C%94%ED%8C%94%EA%B4%80%EC%A0%88%EC%97%94%ED%99%98+%28%EC%A3%BC%29%EC%95%84%EB%A7%88%EC%A1%B4%ED%97%88%EB%B8%8C&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EB%9D%BC%EC%9D%B4%EB%B8%8C+%EB%B9%84%ED%94%BC%EB%8D%94%EC%8A%A4%28Ten+Billion+Live+Bifidus%29+%28%EC%A3%BC%29%EB%B9%84%ED%94%BC%EB%8F%84&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%83%9D+%EC%9C%A0%EC%82%B0%EA%B7%A0+%EB%B9%84%ED%94%BC%EB%8D%94%EC%8A%A4+%EB%9D%BD%ED%86%A0+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0+%EC%B6%A9%EC%A3%BC%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%83%9D+%EC%9C%A0%EC%82%B0%EA%B7%A0+%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84+%EC%97%A0%EC%97%90%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%ED%85%8D%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%83%9D%EC%9C%A0%EC%82%B0%EA%B7%A0+%2B+%EB%A9%B4%EC%97%AD%ED%94%8C%EB%9F%AC%EC%8A%A4+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0+%EC%B6%A9%EC%A3%BC%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%83%9D%EC%9C%A0%EC%82%B0%EA%B7%A0+%ED%8A%B8%EB%A6%AC%ED%94%8C%EC%BC%80%EC%96%B4+%28%EC%A3%BC%29%EC%84%9C%ED%9D%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%83%9D%EC%9C%A0%EC%82%B0%EA%B7%A0+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+18+%EC%BD%9C%EB%A7%88%EB%B9%84%EC%95%A4%EC%97%90%EC%9D%B4%EC%B9%98%28%EC%A3%BC%29%EC%9D%8C%EC%84%B1%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%86%8C%EB%A6%AC%EB%82%98%EB%8A%94+%ED%94%84%EB%A1%9C%2B%ED%94%84%EB%A6%AC%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%EC%BD%94%EC%8A%A4%EB%A7%A5%EC%8A%A4%EC%97%94%EB%B9%84%ED%8B%B0%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%9C%A0%EC%82%B0%EA%B7%A0+%28%EC%A3%BC%29%EC%84%9C%ED%9D%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%9C%A0%EC%82%B0%EA%B7%A0+%EC%BD%94%EC%8A%A4%EB%A7%A5%EC%8A%A4%EC%97%94%EB%B9%84%ED%8B%B0%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%9C%A0%EC%82%B0%EA%B7%A0+ABC+%EC%BD%94%EC%8A%A4%EB%A7%A5%EC%8A%A4%EC%97%94%EB%B9%84%ED%8B%B0%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%9C%A0%EC%82%B0%EA%B7%A0+%EB%B0%B8%EB%9F%B0%EC%8A%A4+%EC%97%A0%EC%97%90%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%ED%85%8D%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%9C%A0%EC%82%B0%EA%B7%A0+%EC%95%84%EC%97%B0%26%EB%B9%84%ED%83%80%EB%AF%BCD+%EC%BD%94%EC%8A%A4%EB%A7%A5%EC%8A%A4%EC%97%94%EB%B9%84%ED%8B%B0%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%9C%A0%EC%82%B0%EA%B7%A0+%EC%BA%A1%EC%8A%90+%EC%BD%94%EC%8A%A4%EB%A7%A5%EC%8A%A4%EC%97%94%EB%B9%84%ED%8B%B0%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%9C%A0%EC%82%B0%EA%B7%A0+%ED%82%A4%EC%A6%88+%ED%86%A1%ED%86%A1+%ED%95%98%EC%9D%B4%28hi%29+%EC%BD%9C%EB%A7%88%EB%B9%84%EC%95%A4%EC%97%90%EC%9D%B4%EC%B9%98%28%EC%A3%BC%29%EC%9D%8C%EC%84%B1%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%9C%A0%EC%82%B0%EA%B7%A0+%ED%8C%9D%ED%95%91+%ED%86%A1%ED%86%A1+%EC%BD%94%EC%8A%A4%EB%A7%A5%EC%8A%A4%EC%97%94%EB%B9%84%ED%8B%B0%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%9C%A0%EC%82%B0%EA%B7%A0+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0+%EC%B6%A9%EC%A3%BC%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%9C%A0%EC%82%B0%EA%B7%A0+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%EC%97%A0%EC%97%90%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%ED%85%8D%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%EC%9C%A0%EC%82%B0%EA%B7%A0%2B%EB%B0%94%EB%82%98%EB%B0%94+%EC%97%A0%EC%97%90%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%ED%85%8D%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%EC%BD%9C%EB%A7%88%EB%B9%84%EC%95%A4%EC%97%90%EC%9D%B4%EC%B9%98%28%EC%A3%BC%29%EC%9D%8C%EC%84%B1%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%EC%83%9D%EC%9C%A0%EC%82%B0%EA%B7%A0+%EB%A7%A5%EC%8A%A4+%EC%BD%94%EC%8A%A4%EB%A7%A5%EC%8A%A4%EC%97%94%EB%B9%84%ED%8B%B0%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%ED%94%8C%EB%9F%AC%EC%8A%A4%2B+%EC%A3%BC%29%ED%8C%9C%ED%81%AC%EB%A1%9C%EC%8A%A4&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84+%ED%8C%A8%EB%B0%80%EB%A6%AC+%EC%9C%A0%EC%82%B0%EA%B7%A0+%EC%BD%9C%EB%A7%88%EB%B9%84%EC%95%A4%EC%97%90%EC%9D%B4%EC%B9%98%28%EC%A3%BC%29%EC%9D%8C%EC%84%B1%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%ED%95%91%ED%81%AC%EC%9C%A0%EC%82%B0%EA%B7%A0+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0+%EC%B6%A9%EC%A3%BC%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5+%ED%95%98%EB%A3%A8%EC%9C%A0%EC%82%B0%EA%B7%A0+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0+%EC%B6%A9%EC%A3%BC%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5%EC%BD%9C%EC%9C%A0%EC%82%B0%EA%B7%A0+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0+%EC%B6%A9%EC%A3%BC%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5%ED%8F%AC%EC%8A%A4%ED%8A%B8%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%28%EC%A3%BC%29%ED%95%9C%ED%92%8D%EB%84%A4%EC%9D%B4%EC%B2%98%ED%8C%9C&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%EC%97%A0%EC%97%90%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%ED%85%8D%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%EC%96%B5%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%EC%BD%94%EC%8A%A4%EB%A7%A5%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=100%ED%94%84%EB%A1%9C+%EC%8B%9D%EB%AC%BC%EC%84%B1+%EC%B2%A0%EB%B6%84%EC%97%BD%EC%82%B0+%28%EC%A3%BC%29%EC%BC%80%EC%9D%B4%EC%A7%80%EC%95%A4%EC%97%90%ED%94%84&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EB%8C%80%EB%A5%BC+%EC%9C%84%ED%95%9C+%EA%B8%B0%EC%96%B5%EB%A0%A5+%EC%97%85%28UP%29+%ED%99%8D%EC%82%BC+%28%EC%A3%BC%29%EA%B1%B4%EB%B3%B4&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%96%B5+%EC%83%9D+%EC%9C%A0%EC%82%B0%EA%B7%A0+%2B+%ED%94%84%EB%A6%AC%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0+%EC%B6%A9%EC%A3%BC%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%96%B5+%EC%83%9D%EC%9C%A0%EC%82%B0%EA%B7%A0+%EB%A9%B4%EC%97%AD%EB%B9%84%ED%83%80%EB%AF%BCD+%EC%97%A0%EC%97%90%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%ED%85%8D%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%96%B5+%EC%83%9D%EC%9C%A0%EC%82%B0%EA%B7%A0+%ED%82%A4%EC%A6%88+%EC%97%A0%EC%97%90%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%ED%85%8D%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%96%B5+%EC%83%9D%EC%9C%A0%EC%82%B0%EA%B7%A0+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%EC%97%A0%EC%97%90%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%ED%85%8D%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%96%B5+%EC%83%9D%EC%9C%A0%EC%82%B0%EA%B7%A0+%ED%94%84%EB%A6%AC%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%EB%8B%A4%EC%9D%B4%EC%96%B4%ED%8A%B8+%EC%97%A0%EC%97%90%EC%8A%A4%EB%B0%94%EC%9D%B4%EC%98%A4%ED%85%8D%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%96%B5+%EC%9C%A0%EC%82%B0%EA%B7%A0+17%EC%A2%85+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%28%EC%A3%BC%29%ED%8C%9C%ED%88%AC%ED%8C%9C2%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%96%B5+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%28%EC%A3%BC%29%EC%94%A8%ED%8B%B0%EC%94%A8%EB%B0%94%EC%9D%B4%EC%98%A4&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%96%B5+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%EC%83%9D%EC%9C%A0%EC%82%B0%EA%B7%A0+%ED%94%84%EB%A6%AC%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%ED%81%90%EC%96%B4%EB%9D%BC%EB%B2%A8%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%A2%85+%EB%A1%9C%EC%96%84+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%A2%85+%EB%B3%B5%ED%95%A9%EC%BD%94%ED%8C%85%EC%9C%A0%EC%82%B0%EA%B7%A0+%EB%B9%84%28B%29+%EC%9D%BC%EB%8F%99%EB%B0%94%EC%9D%B4%EC%98%A4%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%A2%85+%EB%B3%B5%ED%95%A9%EC%BD%94%ED%8C%85%EC%9C%A0%EC%82%B0%EA%B7%A0+%EC%97%90%EC%9D%B4%28A%29+%EC%9D%BC%EB%8F%99%EB%B0%94%EC%9D%B4%EC%98%A4%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%A2%85+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%EC%97%98%EC%97%A0%28LM%29+%EC%A3%BC%EC%8B%9D%ED%9A%8C%EC%82%AC+%EB%9D%BD%ED%86%A0%EB%A9%94%EC%9D%B4%EC%8A%A8&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%A2%85+%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0+250B+%EC%9D%BC%EB%8F%99%EB%B0%94%EC%9D%B4%EC%98%A4%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%A2%85+%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0+%EC%97%A0%EC%99%80%EC%9D%B4%2810+Strains+Blend+MY%29+%EC%9D%BC%EB%8F%99%EB%B0%94%EC%9D%B4%EC%98%A4%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%A2%85+%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0+%EC%98%A4%EC%97%98+%2810+Strains+Blend+OL%29+%3C%EC%A0%84%EB%9F%89%EC%88%98%EC%B6%9C%EC%9A%A9%3E+%EC%9D%BC%EB%8F%99%EB%B0%94%EC%9D%B4%EC%98%A4%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%A2%85+%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0+%EC%A7%80%EC%94%A8%2810+Strains+Blend+GC%29+%3C%EC%A0%84%EB%9F%89%EC%88%98%EC%B6%9C%EC%9A%A9%3E+%EC%9D%BC%EB%8F%99%EB%B0%94%EC%9D%B4%EC%98%A4%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%A2%85+%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0+%ED%8B%B0%EC%97%90%EC%9D%B4%EC%B9%98%2810+Stains+Blend+TH%29+%3C%EC%A0%84%EB%9F%89%EC%88%98%EC%B6%9C%EC%9A%A9%3E+%EC%9D%BC%EB%8F%99%EB%B0%94%EC%9D%B4%EC%98%A4%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4%28%EC%A3%BC%29&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%A2%85+%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0-200%EB%B9%84%28200B%29+%28%EC%A3%BC%29%EC%94%A8%ED%8B%B0%EC%94%A8%EB%B0%94%EC%9D%B4%EC%98%A4&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%A2%85%EB%9D%BC%EB%B9%84%EC%84%BC%EA%B6%81%EC%9C%A0%EC%82%B0%EA%B7%A0+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=10%EC%A2%85%EB%B9%84%EB%84%88%EC%8A%A4%EC%9C%A0%EC%82%B0%EA%B7%A0+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# ...
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=17%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EC%98%A4%28O%29+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=1879+%ED%8F%B4%EB%A6%AC%ED%8C%8C%EC%9B%8C+%EC%97%90%EB%84%88%EC%A7%80+%28%EC%A3%BC%29%ED%8C%9C%ED%85%8D%EC%BD%94%EB%A6%AC%EC%95%84&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=18%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-2800+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=1900+%EB%B9%84%EC%98%A4%ED%8B%B4+%EB%A7%A5%EC%8A%A4%ED%97%A4%EC%96%B4+%28%EC%A3%BC%29%EC%98%A4%ED%88%AC%EB%B0%94%EC%9D%B4%EC%98%A4&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85+%EC%83%9D%EC%9C%A0%EC%82%B0%EA%B7%A0+%EC%85%80%EB%A0%88%EB%8A%84+%EC%95%84%EC%97%B0+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%EB%8F%99%EC%84%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%9C%28%EC%A3%BC%29+%EC%95%88%EC%84%B1%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85+%EC%9C%A0%EC%82%B0%EA%B7%A0+%EB%B3%B5%ED%95%A9%EC%B2%B4+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85+%ED%8D%BC%EC%8A%A4%ED%8A%B8%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4+%28%EC%A3%BC%29%ED%95%9C%EB%AF%B8%EC%96%91%ED%96%89+%EC%84%A0%EC%9C%A0%EA%B3%B5%EC%9E%A5&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4-1000+%EC%A3%BC%EC%8B%9D%ED%9A%8C%EC%82%AC+%EB%9D%BD%ED%86%A0%EB%A9%94%EC%9D%B4%EC%8A%A8&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85+%ED%94%84%EB%A1%9C%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8B%B1%EC%8A%A4-2000+%EC%A3%BC%EC%8B%9D%ED%9A%8C%EC%82%AC+%EB%9D%BD%ED%86%A0%EB%A9%94%EC%9D%B4%EC%8A%A8&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%EB%B3%B5%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EC%97%A0%EC%A7%80%28MG%29-2000+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0+200B+GN+%28%EC%A3%BC%29%EC%BC%80%EB%B9%84%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0+RS-200B+GN+%28%EC%A3%BC%29%EC%BC%80%EB%B9%84%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0+RSD-200B+GN+%28%EC%A3%BC%29%EC%BC%80%EB%B9%84%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0-4500+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0-P+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0-RS+200B+%28%EC%A3%BC%29%EC%94%A8%ED%8B%B0%EC%94%A8%EB%B0%94%EC%9D%B4%EC%98%A4&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0-%EC%95%8C%EC%97%90%EC%8A%A4+200%EB%B9%84+%EB%89%B4%2819%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0-RS+200B+New%29+%28%EC%A3%BC%29%EC%94%A8%ED%8B%B0%EC%94%A8%EB%B0%94%EC%9D%B4%EC%98%A4&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0-%EC%95%8C%EC%97%90%EC%8A%A4%EB%94%94%28RSD%29+%28%EC%A3%BC%29%EC%94%A8%ED%8B%B0%EC%94%A8%EB%B0%94%EC%9D%B4%EC%98%A4&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-2200+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-2400+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 📄 3/418 페이지 수집 완료
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-2500+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-2700+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-3000+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-3300+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-3500+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-3600+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-3800+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-3900+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-4000+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-4200+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-4300+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%29-4400+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%292-2400+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%292-2700+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# 🔴 Google Image Search 실패: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%292-3000+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-5-1375550906.py in fetch_image_url(query, cse_id, api_key)
#      29         response = requests.get(url, params=params, timeout=5)
# ---> 30         response.raise_for_status()
#      31         results = response.json()
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://www.googleapis.com/customsearch/v1?q=19%EC%A2%85%ED%98%BC%ED%95%A9%EC%9C%A0%EC%82%B0%EA%B7%A0%EB%94%94%EC%95%84%EC%9D%B4%28DI%292-3000+%28%EC%A3%BC%29%EB%A9%94%EB%94%94%EC%98%A4%EC%A0%A0&cx=e717d84b258f541ed&key=AIzaSyD5nywUMssMS-csd3PqT4tY5O1cePMHP5w&searchType=image&num=1&imgSize=medium&safe=active
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-5-1375550906.py in <cell line: 0>()
#     246
#     247     # Step 1: 문서 수집
# --> 248     documents = fetch_all_documents(url, api_key)
#     249
#     250     # Step 2: 벡터스토어 생성 및 문서 업로드
#
# /tmp/ipython-input-5-1375550906.py in fetch_all_documents(api_url, api_key, num_of_rows)
#     115         response.raise_for_status() # 오류가 있으면 예외 발생시킴 (예: 404, 500)
#     116         page_json = response.json() # 페이지 응답 JSON 파싱
# --> 117         docs = json_to_documents(page_json) # 해당 페이지의 JSON을 Document 객체로 변환
#     118         all_documents.extend(docs) # 변환된 문서들을 all_documents 리스트에 추가
#     119         print(f"📄 {page}/{total_pages} 페이지 수집 완료")
#
# /tmp/ipython-input-5-1375550906.py in json_to_documents(api_json)
#      63         if google_cse_id and google_api_key and product_name:
#      64             query = f"{product_name} {manufacturer}" # 제품명과 제조사를 함께 검색 쿼리로 사용
# ---> 65             image_url = fetch_image_url(query, google_cse_id, google_api_key)
#      66
#      67         text = f"""
#
# /tmp/ipython-input-5-1375550906.py in fetch_image_url(query, cse_id, api_key)
#      34             return items[0]["link"]
#      35     except Exception as e:
# ---> 36         print(f"🔴 Google Image Search 실패: {e}")
#      37
#      38     return ""
#
# KeyboardInterrupt:

# %%
# import os
# import time
# import requests
# from pprint import pprint
# from langchain_core.documents import Document
# from langchain_openai import OpenAIEmbeddings, ChatOpenAI
# from langchain_pinecone import PineconeVectorStore
# from langchain.text_splitter import RecursiveCharacterTextSplitter
# from pinecone import Pinecone
# from langchain.chains import RetrievalQA

# from langchain_openai import OpenAIEmbeddings
# from langchain_pinecone import PineconeVectorStore

# # 존재하는 인덱스에 접근/검색

# # Initialize Pinecone
# pc = Pinecone(api_key=os.environ['PINECONE_API_KEY'])

# # Reference the existing index
# index_name = 'health-supplement-rag'
# index = pc.Index(index_name)

# vector_store = PineconeVectorStore(
#     index=index,
#     embedding=embeddings
# )

# %%
# retriever = vector_store.as_retriever(
#     search_type='similarity',
#     search_kwargs={'k': 3} # 유사한 문서 3개까지 검색
# )
# print(retriever.invoke('피로개선에 도움이 되는 영양제는?'))
# Out:
# [Document(id='8609cb9f-665e-4356-bfde-f54f23470036', metadata={'기준규격': '1) 성상 : 이미, 이취가 없고 고유의 향미가 있는 갈색의 장방형 제피정제 \n2) 로사빈 : 표시량(6 mg /1,000 mg)의 80~120% \n3) 나이아신 : 표시량(7.5 mgNE /1,000 mg)의 80~150%\n4) 납(mg/kg) : 1.0 이하 \n5) 카드뮴(mg/kg) : 0.5 이하 \n6) 총수은(mg/Kg) : 0.5 이하 \n7) 총비소(mg/Kg) : 1.0 이하 \n8) 대장균군 : 음성 \n9) 붕해시험 : 적합', '등록일자': '20040015107744', '제조사': '(주)유유헬스케어'}, page_content='제품명: 피로개선에 도움을 줄 수 있는 홍경천\n제조사: (주)유유헬스케어\n기능성: 스트레스로 인한 피로개선에 도움을 줄 수 있음.\n\n①체내 에너지 생성에 필요\n섭취 시 주의사항: 특정원료에 알레르기가 있거나 질병치료, 약물투여 중인 분은 섭취 전 전문가와 상의하십시오.  \n제품 개봉시 포장재에 의해 상처를 입을 수 있으니 주의하십시오.\n보관조건: 직사광선 및 고온다습한 곳을 피해 서늘한 곳에 보관하십시오.\n유통기한: 제조일로부터 24개월까지'), Document(id='0c0a6382-6cbc-4971-af77-52a8bce0caea', metadata={'기준규격': '성상 : 이미, 이취가 없고 고유의 향미가 있는 갈색의 코팅정제\r\n진세노사이드 Rb1,Rg1 및 Rg3의 합 : 80%이상 (표시량:3mg/1,660mg)\r\n비타민A : 표시량의 80~150% (표시량:485ugRE/1,660mg)\r\n비타민B1 : 표시량의 80~180% (표시량:16mg/1,660mg)\r\n비타민B2 : 표시량의 80~180% (표시량:1.5mg/1,660mg)\r\n비타민B6 : 표시량의 80~150% (표시량:16.5mg/1,660mg)\r\n비타민B12 : 표시량의 80~180% (표시량:115ug/1,660mg)\r\n비타민D : 표시량의 80~180% (표시량:22ug/1,660mg)\r\n비타민E : 표시량의 80~150% (표시량:16mgα-TE/1,660mg)\r\n나이아신 : 표시량의 80~150% (표시량:4.5mgNE/1,660mg)\r\n망간 : 표시량의 80~150% (표시량:7mg/1,660mg)\r\n아연 : 표시량의 80~150% (표시량:6mg/1,660mg)\r\n판토텐산 : 표시량의 80~180% (표시량:4.5mg/1,660mg)\r\n붕해시험 : 적합 (기준:60분이내)\r\n대장균군 : 적합 (기준:음성)', '등록일자': '2013002000860', '제조사': '(주)오투바이오'}, page_content='제품명: 힘내요 청춘 피로개선\n제조사: (주)오투바이오\n기능성: ①면역력 증진에 도움을 줄 수 있음②피로개선에 도움을 줄 수 있음③혈소판 응집 억제를 통한 혈액흐름에 도움을 줄 수 있음④기억력 개선에 도움을 줄 수 있음⑤항산화에 도움을 줄 수 있음\n\n①정상적인 면역기능에 필요②정상적인 세포분열에 필요\n\n①어두운 곳에서 시각 적응을 위해 필요②피부와 점막을 형성하고 기능을 유지하는데 필요③상피세포의 성장과 발달에 필요\n\n①탄수화물과 에너지 대사에 필요\n\n①체내 에너지 생성에 필요\n\n①체내 에너지 생성에 필요\n\n①단백질 및 아미노산 이용에 필요②혈액의 호모시스테인 수준을 정상으로 유지하는데 필요\n\n①정상적인 엽산 대사에 필요\n\n①칼슘과 인이 흡수되고 이용되는데 필요②뼈의 형성과 유지에 필요③골다공증발생 위험 감소에 도움을 줌\n\n①유해산소로부터 세포를 보호하는데 필요\n\n①체내 에너지 생성에 필요\n\n①뼈 형성에 필요②에너지 이용에 필요③유해산소로부터 세포를 보호하는데 필요\n\n①지방, 탄수화물, 단백질 대사와 에너지 생성에 필요\n섭취 시 주의사항: 의약품(당뇨치료제, 혈액항응고제) 복용 시 섭취에 주의\n보관조건: 직사광선을 피하여 서늘한 곳에 보관\n유통기한: 24개월'), Document(id='5efef7d6-b7e0-4411-a227-0286bb220c2e', metadata={'기준규격': '1.성상: 이미, 이취가 없고, 고유의 향미를 가진 갈색의 대환\n2.진세노사이드 Rg1+Rb1+Rg3의 합\n  *최종제품: 표시량(5mg/5g)의 80%이상\n3.대장균군: 음성', '등록일자': '20040020031329', '제조사': '대동고려삼(주)'}, page_content='제품명: 원광공진단\n제조사: 대동고려삼(주)\n기능성: ①면역력 증진에 도움을 줄 수 있음②피로개선에 도움을 줄 수 있음③혈소판 응집 억제를 통한 혈액흐름에 도움을 줄 수 있음④기억력 개선에 도움을 줄 수 있음⑤항산화에 도움을 줄 수 있음\n섭취 시 주의사항: 의약품(당뇨치료제, 혈액항응고제) 복용 시 섭취에 주의\n보관조건: 직사광선을 피하고 습기가 없는 서늘한 곳에 보관하십시오\n유통기한: 제조일로부터3년까지')]

# %%
# from langchain_openai import ChatOpenAI

# llm = ChatOpenAI(
#     model_name="gpt-4.1-mini",  #
#     temperature=0.3, # 0.3 답변이 신중하고 일관
#     max_tokens=512
# )

# %%
# from langchain.chains import RetrievalQA

# qa_chain = RetrievalQA.from_chain_type(
#     llm=llm,
#     retriever=retriever,           # Step 4에서 만든 것
#     chain_type="stuff",            # "stuff"는 검색 결과를 LLM에 다 넘김
#     return_source_documents=True   # 🔍 근거 문서 포함 응답
# )

# %%
# query = "Ento Probiotics plus Blood sugar care에 대해 알려줘"

# response = qa_chain(query)

# print("🧠 GPT 응답:")
# print(response['result'])
# Out:
# /tmp/ipython-input-15-1546530874.py:3: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = qa_chain(query)
# 🧠 GPT 응답:
# Ento Probiotics plus Blood sugar care는 주식회사 아람에서 제조한 제품으로, 전량 수출용입니다. 이 제품의 주요 기능성은 다음과 같습니다:
#
# - 유산균 증식 및 유해균 억제
# - 배변활동 원활
# - 장 건강에 도움을 줄 수 있음
# - 식후 혈당상승 억제에 도움을 줄 수 있음
#
# 또한, 정상적인 면역기능과 정상적인 세포분열에 필요한 성분을 포함하고 있습니다.
#
# 섭취 시 주의사항은 다음과 같습니다:
# - 질환이 있거나 의약품 복용 시 전문가와 상담할 것
# - 알레르기 체질 등 개인에 따라 과민반응이 나타날 수 있음
# - 어린이가 함부로 섭취하지 않도록 일일섭취량 방법을 지도할 것
# - 이상사례 발생 시 섭취를 중단하고 전문가와 상담할 것
#
# 보관 조건은 직사광선 및 고온다습한 곳을 피하고 서늘한 곳에 보관하며, 어린이의 손에 닿지 않는 곳에 보관해야 합니다.
#
# 유통기한은 제조일부터 24개월입니다.
